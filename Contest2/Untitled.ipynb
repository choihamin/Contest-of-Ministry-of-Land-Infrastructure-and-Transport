# %%
import os
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from tqdm import tqdm
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-855fd5bea06b> in <module>
#       2 from bs4 import BeautifulSoup
#       3 from urllib.request import urlopen
# ----> 4 import pandas as pd
#       5 from tqdm import tqdm
#       6 import pandas as pd
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     142 from pandas.util._print_versions import show_versions
#     143
# --> 144 from pandas.io.api import (
#     145     # excel
#     146     ExcelFile,
#
# ~\anaconda3\lib\site-packages\pandas\io\api.py in <module>
#       6
#       7 from pandas.io.clipboards import read_clipboard
# ----> 8 from pandas.io.excel import ExcelFile, ExcelWriter, read_excel
#       9 from pandas.io.feather_format import read_feather
#      10 from pandas.io.gbq import read_gbq
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\__init__.py in <module>
# ...

# %%
import urllib.request

url = "http://openapi.kepco.co.kr/service/EvInfoServiceV2/getEvSearchList"
key1 = "QD%2F1soJk0R03qtRk4Xzsz7%2FqQ9G0hCAx7Biw1ycmZ3GJMS%2BVS2PkNqedYdjUgR22z240xP%2FsTIweFQI6QdJcDA%3D%3D"
key2 = "QD/1soJk0R03qtRk4Xzsz7/qQ9G0hCAx7Biw1ycmZ3GJMS+VS2PkNqedYdjUgR22z240xP/sTIweFQI6QdJcDA=="
i = 0
pn = 1
num_of_row = 9999
req = urllib.request.urlopen('{}?ServiceKey={}&pageNo={}&numOfRows={}'.format(url, key1, pn, num_of_row))
soup = BeautifulSoup(req, "html.parser")

df = pd.DataFrame(columns=['addr', 'charTp', 'cpId', 'cpNm', 
                           'cpStat', 'cpTp', 'csId', 'csNm',
                           'lat','longi','statUpdateDatetime'])
items = soup.find("items")
for item in tqdm(items.findAll("item")):
    df.loc[i] = [item.addr.text, item.chargetp.text, item.cpid.text, item.cpnm.text,
                 item.cpstat.text, item.cptp.text, item.csid.text, item.csnm.text,
                 item.lat.text, item.longi.text, item.statupdatedatetime.text]
    i += 1
df
# Out:
# 100%|██████████| 2180/2180 [00:09<00:00, 236.52it/s]
#                               addr charTp   cpId  cpNm cpStat cpTp  csId  \
# 0          서울특별시 중구 남대문로 92 1층 주차장      2    811  급속01      1   10    14
# 1     경상남도 남해군 남해읍 심천리 955-1 정문 우측      2    464  급속01      3   10    75
# 2     서울특별시 한강대로 23길 55 4.5F층 달주차장      2    725  급속06      2   10   120
# 3      경상남도 창원시 의창구 도계동 908 쎄씨헤어 앞      1    229  완속03      1    3    81
# 4       부산광역시 해운대구 우동 1413-4 지하주차장      2   6891  급속03      2   10  2605
# ...                            ...    ...    ...   ...    ...  ...   ...
# 2175   경상북도 울릉군 울릉읍 도동리 299 3층 주차장      2  10564  급속02      1    7  4402
# 2176      제주특별자치도 서귀포시 서귀동 305-1 .      2  11045  급속01      1    7  4706
# 2177  경상남도 거제시 둔덕면 방하리 505-1 청마기념관      2  10490  급속01      1    7  4312
# 2178       경상남도 거제시 양정동 981 거제시보건소      2  10489  급속01      4    7  4311
# 2179  충청남도 천안시 동남구 오룡동 189-1 주차장 내      2  10553  급속01      1    7  4388
#
# ...

# %%
import googlemaps

gmaps = googlemaps.Client(key = 'AIzaSyBjM1J80kYgT3jtnngwILrZJ5hDaQPVNT4')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-57b66ee26ff8> in <module>
# ----> 1 import googlemaps
#       2
#       3 gmaps = googlemaps.Client(key = 'AIzaSyBjM1J80kYgT3jtnngwILrZJ5hDaQPVNT4')
#
# ModuleNotFoundError: No module named 'googlemaps'

# %%
df=pd.read_csv('./data/Seoul_Electric.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-d72d2af272ce> in <module>
# ----> 1 import pandas as pd
#       2
#       3 df=pd.read_csv('./data/Seoul_Electric.csv', encoding='utf-8')
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     142 from pandas.util._print_versions import show_versions
#     143
# --> 144 from pandas.io.api import (
#     145     # excel
#     146     ExcelFile,
#
# ~\anaconda3\lib\site-packages\pandas\io\api.py in <module>
#       6
#       7 from pandas.io.clipboards import read_clipboard
# ----> 8 from pandas.io.excel import ExcelFile, ExcelWriter, read_excel
#       9 from pandas.io.feather_format import read_feather
#      10 from pandas.io.gbq import read_gbq
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\__init__.py in <module>
# ----> 1 from pandas.io.excel._base import ExcelFile, ExcelWriter, read_excel
# ...

# %%
import numpy as np

# %%
for e in df.drop(columns=['기간','자치구']).columns:
    df[e] = list(map(lambda x : int(''.join(x.split(',')) if x != '-' else float(np.nan)), df[e]))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-81593196e60a> in <module>
#       1 for e in df.drop(columns=['기간','자치구']).columns:
# ----> 2     df[e] = list(map(lambda x : int(''.join(x.split(',')) if x != '-' else float(np.nan)), df[e]))
#       3 df.head()
#
# <ipython-input-19-81593196e60a> in <lambda>(x)
#       1 for e in df.drop(columns=['기간','자치구']).columns:
# ----> 2     df[e] = list(map(lambda x : int(''.join(x.split(',')) if x != '-' else float(np.nan)), df[e]))
#       3 df.head()
#
# ValueError: cannot convert float NaN to integer
