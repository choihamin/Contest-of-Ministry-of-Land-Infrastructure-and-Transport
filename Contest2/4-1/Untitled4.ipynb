# %%
import pandas as pd
data = pd.read_excel('경부.xlsx')
data
# Out:
#        지점번호  도명  시/군  읍/면 동/리               구간       이정(km)  연장(km)  차로수  \
# 0       101  부산  NaN   금정  구서        구서IC-노포IC        0~5.1     5.1    6
# 1   00101-1  부산  NaN   금정  노포       노포IC-노포JCT      5.1~5.6     0.5    6
# 2   00101-2  부산  NaN   금정  노포      노포JCT-양산JCT     5.6~12.9     7.3    6
# 3       102  경남   양산  NaN  다방       양산JCT-양산IC      12.9~18     5.1    8
# 4       103  경남   양산   상북  석계   양산IC-통도사하이패스IC      18~30.8    12.8    6
# 5   00103-1  울산   울주   삼남  순지  통도사하이패스IC-통도사IC    30.8~32.2     1.4    6
# 6       104  울산   울주   삼남  조일      통도사IC-서울산IC    32.2~38.6     6.4    6
# 7       105  울산   울주   삼남   교      서울산IC-언양JCT    38.6~40.1     1.5    6
# 8       106  울산   울주   언양  반곡       언양JCT-활천IC    40.1~57.3    17.2    4
# 9   00106-1  경북   경주   내남  용장        활천IC-경주IC    57.3~68.2    10.9    4
# 10      107  경북   경주  NaN   율        경주IC-건천IC    68.2~78.7    10.5    4
# 11      108  경북   경주   건천  천포       건천IC-영천JCT    78.7~90.8    12.1    4
# ...

# %%
data = data[['구간', '연장(km)', '차로수', '계']]
data
# Out:
#                  구간  연장(km)  차로수       계
# 0         구서IC-노포IC     5.1    6   71512
# 1        노포IC-노포JCT     0.5    6   66817
# 2       노포JCT-양산JCT     7.3    6   86906
# 3        양산JCT-양산IC     5.1    8   89018
# 4    양산IC-통도사하이패스IC    12.8    6   71192
# 5   통도사하이패스IC-통도사IC     1.4    6   68352
# 6       통도사IC-서울산IC     6.4    6   65305
# 7       서울산IC-언양JCT     1.5    6   58585
# 8        언양JCT-활천IC    17.2    4   49423
# 9         활천IC-경주IC    10.9    4   45602
# 10        경주IC-건천IC    10.5    4   50636
# 11       건천IC-영천JCT    12.1    4   50749
# 12       영천JCT-영천IC     5.6    4   30651
# 13        영천IC-경산IC    16.4    6   47778
# 14      경산IC-동대구JCT     9.3    8   74842
# 15     동대구JCT-도동JCT     4.0    8  109530
# 16      도동JCT-북대구IC     7.5    8  132091
# 17      북대구IC-금호JCT     5.5    8  144977
# 18     금호JCT-칠곡물류IC    10.7    8  104824
# 19      칠곡물류IC-왜관IC     3.2    8  107716
# 20       왜관IC-남구미IC    14.0    8   87956
# 21       남구미IC-구미IC     4.9    8   79940
# ...
